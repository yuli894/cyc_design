# %% [markdown]
# <a href="https://colab.research.google.com/github/yuli894/cyc_design/blob/main/af/examples/af_cyc_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #af_cyc_design
#
# **Cyclic peptide structure prediction and design using AlphaFold**
#
# Stephen Rettie, Katelyn Campbell, Asim Bera, Alex Kang, Simon Kozlov, Joshmyn De La Cruz, Victor Adebomi, Guangfeng Zhou, Frank DiMaio, Sergey Ovchinnikov, Gaurav Bhardwaj
#
# doi: https://doi.org/10.1101/2023.02.25.529956

# %%
#@title setup (~2 minutes)
# %%time
import os
if not os.path.isdir("params"):
  # get code
  os.system("pip -q install git+https://github.com/sokrypton/ColabDesign.git@v1.1.1")
  # for debugging
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")
  # download params
  os.system("mkdir params")
  os.system("apt-get install aria2 -qq")
  os.system("aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar")
  os.system("tar -xf alphafold_params_2022-12-06.tar -C params")

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
from colabdesign import mk_afdesign_model, clear_mem
from IPython.display import HTML
from google.colab import files
import numpy as np

import jax
import jax.numpy as jnp
from colabdesign.af.alphafold.common import residue_constants

def get_pdb(pdb_code=""):
  if pdb_code is None or pdb_code == "":
    upload_dict = files.upload()
    pdb_string = upload_dict[list(upload_dict.keys())[0]]
    with open("tmp.pdb","wb") as out: out.write(pdb_string)
    return "tmp.pdb"
  elif os.path.isfile(pdb_code):
    return pdb_code
  elif len(pdb_code) == 4:
    os.system(f"wget -qnc https://files.rcsb.org/view/{pdb_code}.pdb")
    return f"{pdb_code}.pdb"
  else:
    os.system(f"wget -qnc https://alphafold.ebi.ac.uk/files/AF-{pdb_code}-F1-model_v3.pdb")
    return f"AF-{pdb_code}-F1-model_v3.pdb"

def add_cyclic_offset(self, offset_type=2):
  '''add cyclic offset to connect N and C term'''
  def cyclic_offset(L):
    i = np.arange(L)
    ij = np.stack([i,i+L],-1)
    offset = i[:,None] - i[None,:]
    c_offset = np.abs(ij[:,None,:,None] - ij[None,:,None,:]).min((2,3))
    if offset_type == 1:
      c_offset = c_offset
    elif offset_type >= 2:
      a = c_offset < np.abs(offset)
      c_offset[a] = -c_offset[a]
    if offset_type == 3:
      idx = np.abs(c_offset) > 2
      c_offset[idx] = (32 * c_offset[idx] )/  abs(c_offset[idx])
    return c_offset * np.sign(offset)
  idx = self._inputs["residue_index"]
  offset = np.array(idx[:,None] - idx[None,:])

  if self.protocol == "binder":
    c_offset = cyclic_offset(self._binder_len)
    offset[self._target_len:,self._target_len:] = c_offset

  if self.protocol in ["fixbb","partial","hallucination"]:
    Ln = 0
    for L in self._lengths:
      offset[Ln:Ln+L,Ln:Ln+L] = cyclic_offset(L)
      Ln += L
  self._inputs["offset"] = offset

def add_rg_loss(self, weight=0.1):
  '''add radius of gyration loss'''
  def loss_fn(inputs, outputs):
    xyz = outputs["structure_module"]
    ca = xyz["final_atom_positions"][:,residue_constants.atom_order["CA"]]
    rg = jnp.sqrt(jnp.square(ca - ca.mean(0)).sum(-1).mean() + 1e-8)
    rg_th = 2.38 * ca.shape[0] ** 0.365
    rg = jax.nn.elu(rg - rg_th)
    return {"rg":rg}
  self._callbacks["model"]["loss"].append(loss_fn)
  self.opt["weights"]["rg"] = weight
# Out:
# CPU times: user 1.54 s, sys: 189 ms, total: 1.73 s
# Wall time: 1min 48s

# %% [markdown]
# # fixed backbone design (fixbb) (~2 minutes)
# For a given protein backbone, generate/design a new sequence that AlphaFold thinks folds into that conformation.

# %%
clear_mem()
af_model = mk_afdesign_model(protocol="fixbb")
af_model.prep_inputs(pdb_filename=get_pdb("7m28"), chain="A")
add_cyclic_offset(af_model, offset_type=2)

print("length",  af_model._len)
print("weights", af_model.opt["weights"])
# Out:
# length 7
# weights {'con': 0.0, 'dgram_cce': 1.0, 'exp_res': 0.0, 'fape': 0.0, 'helix': 0.0, 'pae': 0.0, 'plddt': 0.0, 'rmsd': 0.0, 'seq_ent': 0.0}

# %%
import matplotlib.pyplot as plt
plt.imshow(af_model._inputs["offset"], cmap="bwr")
plt.colorbar(label="Offset Values")
plt.title("Residue Offset Matrix")
plt.xlabel("Residue Index")
plt.ylabel("Residue Index")
plt.show()

# %%
af_model.restart()
af_model.design_3stage()
# Out:
# Stage 1: running (logits → soft)
# 1 models [4] recycles 0 hard 0 soft 0.00 temp 1 seqid 0 loss 2.35 dgram_cce 2.35 plddt 0.79 ptm 0.06 rmsd 1.08
# 2 models [4] recycles 0 hard 0 soft 0.01 temp 1 seqid 0 loss 2.38 dgram_cce 2.38 plddt 0.75 ptm 0.05 rmsd 1.57
# 3 models [1] recycles 0 hard 0 soft 0.01 temp 1 seqid 0 loss 2.95 dgram_cce 2.95 plddt 0.68 ptm 0.06 rmsd 4.37
# 4 models [4] recycles 0 hard 0 soft 0.01 temp 1 seqid 0 loss 2.41 dgram_cce 2.41 plddt 0.71 ptm 0.06 rmsd 0.68
# 5 models [3] recycles 0 hard 0 soft 0.02 temp 1 seqid 0.14 loss 2.28 dgram_cce 2.28 plddt 0.80 ptm 0.05 rmsd 0.96
# 6 models [2] recycles 0 hard 0 soft 0.02 temp 1 seqid 0 loss 2.38 dgram_cce 2.38 plddt 0.66 ptm 0.06 rmsd 2.30
# 7 models [3] recycles 0 hard 0 soft 0.02 temp 1 seqid 0 loss 2.34 dgram_cce 2.34 plddt 0.79 ptm 0.05 rmsd 1.94
# 8 models [3] recycles 0 hard 0 soft 0.03 temp 1 seqid 0 loss 2.29 dgram_cce 2.29 plddt 0.78 ptm 0.05 rmsd 1.61
# 9 models [0] recycles 0 hard 0 soft 0.03 temp 1 seqid 0 loss 2.37 dgram_cce 2.37 plddt 0.82 ptm 0.06 rmsd 1.09
# 10 models [4] recycles 0 hard 0 soft 0.03 temp 1 seqid 0 loss 2.25 dgram_cce 2.25 plddt 0.75 ptm 0.06 rmsd 0.92
# 11 models [1] recycles 0 hard 0 soft 0.04 temp 1 seqid 0 loss 2.24 dgram_cce 2.24 plddt 0.72 ptm 0.06 rmsd 0.81
# 12 models [3] recycles 0 hard 0 soft 0.04 temp 1 seqid 0 loss 2.24 dgram_cce 2.24 plddt 0.74 ptm 0.05 rmsd 1.36
# 13 models [3] recycles 0 hard 0 soft 0.04 temp 1 seqid 0.14 loss 2.16 dgram_cce 2.16 plddt 0.83 ptm 0.06 rmsd 0.70
# 14 models [3] recycles 0 hard 0 soft 0.05 temp 1 seqid 0.14 loss 2.06 dgram_cce 2.06 plddt 0.83 ptm 0.06 rmsd 0.46
# 15 models [2] recycles 0 hard 0 soft 0.05 temp 1 seqid 0.14 loss 2.16 dgram_cce 2.16 plddt 0.81 ptm 0.06 rmsd 0.60
# 16 models [0] recycles 0 hard 0 soft 0.05 temp 1 seqid 0 loss 2.13 dgram_cce 2.13 plddt 0.77 ptm 0.06 rmsd 1.18
# 17 models [0] recycles 0 hard 0 soft 0.06 temp 1 seqid 0 loss 2.09 dgram_cce 2.09 plddt 0.77 ptm 0.06 rmsd 1.02
# 18 models [0] recycles 0 hard 0 soft 0.06 temp 1 seqid 0.14 loss 2.05 dgram_cce 2.05 plddt 0.85 ptm 0.06 rmsd 0.81
# 19 models [3] recycles 0 hard 0 soft 0.06 temp 1 seqid 0.14 loss 1.94 dgram_cce 1.94 plddt 0.84 ptm 0.06 rmsd 0.41
# 20 models [1] recycles 0 hard 0 soft 0.07 temp 1 seqid 0.14 loss 2.16 dgram_cce 2.16 plddt 0.75 ptm 0.06 rmsd 1.13
# 21 models [1] recycles 0 hard 0 soft 0.07 temp 1 seqid 0.14 loss 1.99 dgram_cce 1.99 plddt 0.79 ptm 0.06 rmsd 0.80
# 22 models [0] recycles 0 hard 0 soft 0.07 temp 1 seqid 0.14 loss 2.13 dgram_cce 2.13 plddt 0.85 ptm 0.06 rmsd 0.83
# 23 models [1] recycles 0 hard 0 soft 0.08 temp 1 seqid 0.14 loss 2.11 dgram_cce 2.11 plddt 0.75 ptm 0.06 rmsd 1.36
# 24 models [2] recycles 0 hard 0 soft 0.08 temp 1 seqid 0.14 loss 2.16 dgram_cce 2.16 plddt 0.82 ptm 0.06 rmsd 0.77
# 25 models [4] recycles 0 hard 0 soft 0.08 temp 1 seqid 0.14 loss 2.02 dgram_cce 2.02 plddt 0.78 ptm 0.06 rmsd 0.66
# 26 models [2] recycles 0 hard 0 soft 0.09 temp 1 seqid 0.14 loss 2.04 dgram_cce 2.04 plddt 0.78 ptm 0.06 rmsd 0.77
# 27 models [4] recycles 0 hard 0 soft 0.09 temp 1 seqid 0.14 loss 1.93 dgram_cce 1.93 plddt 0.85 ptm 0.06 rmsd 0.77
# 28 models [1] recycles 0 hard 0 soft 0.09 temp 1 seqid 0.14 loss 1.98 dgram_cce 1.98 plddt 0.77 ptm 0.06 rmsd 0.99
# 29 models [1] recycles 0 hard 0 soft 0.10 temp 1 seqid 0.14 loss 1.99 dgram_cce 1.99 plddt 0.77 ptm 0.06 rmsd 0.63
# 30 models [0] recycles 0 hard 0 soft 0.10 temp 1 seqid 0.14 loss 1.98 dgram_cce 1.98 plddt 0.81 ptm 0.06 rmsd 0.94
# 31 models [2] recycles 0 hard 0 soft 0.10 temp 1 seqid 0.14 loss 2.24 dgram_cce 2.24 plddt 0.85 ptm 0.06 rmsd 0.78
# 32 models [2] recycles 0 hard 0 soft 0.11 temp 1 seqid 0.14 loss 2.14 dgram_cce 2.14 plddt 0.87 ptm 0.06 rmsd 0.93
# 33 models [0] recycles 0 hard 0 soft 0.11 temp 1 seqid 0.14 loss 1.98 dgram_cce 1.98 plddt 0.84 ptm 0.06 rmsd 0.60
# 34 models [0] recycles 0 hard 0 soft 0.11 temp 1 seqid 0.14 loss 2.05 dgram_cce 2.05 plddt 0.79 ptm 0.06 rmsd 0.96
# 35 models [2] recycles 0 hard 0 soft 0.12 temp 1 seqid 0.14 loss 2.04 dgram_cce 2.04 plddt 0.82 ptm 0.06 rmsd 0.64
# 36 models [3] recycles 0 hard 0 soft 0.12 temp 1 seqid 0.14 loss 1.99 dgram_cce 1.99 plddt 0.84 ptm 0.06 rmsd 0.86
# 37 models [2] recycles 0 hard 0 soft 0.12 temp 1 seqid 0.29 loss 2.15 dgram_cce 2.15 plddt 0.80 ptm 0.06 rmsd 0.82
# 38 models [2] recycles 0 hard 0 soft 0.13 temp 1 seqid 0.14 loss 2.02 dgram_cce 2.02 plddt 0.86 ptm 0.06 rmsd 1.03
# 39 models [4] recycles 0 hard 0 soft 0.13 temp 1 seqid 0.14 loss 2.05 dgram_cce 2.05 plddt 0.83 ptm 0.06 rmsd 0.73
# 40 models [0] recycles 0 hard 0 soft 0.13 temp 1 seqid 0.14 loss 1.97 dgram_cce 1.97 plddt 0.76 ptm 0.06 rmsd 0.68
# 41 models [4] recycles 0 hard 0 soft 0.14 temp 1 seqid 0.14 loss 2.27 dgram_cce 2.27 plddt 0.80 ptm 0.06 rmsd 0.84
# 42 models [1] recycles 0 hard 0 soft 0.14 temp 1 seqid 0.14 loss 2.09 dgram_cce 2.09 plddt 0.74 ptm 0.06 rmsd 1.02
# 43 models [2] recycles 0 hard 0 soft 0.14 temp 1 seqid 0.14 loss 2.09 dgram_cce 2.09 plddt 0.79 ptm 0.06 rmsd 0.75
# 44 models [2] recycles 0 hard 0 soft 0.15 temp 1 seqid 0.14 loss 1.79 dgram_cce 1.79 plddt 0.79 ptm 0.06 rmsd 1.27
# 45 models [4] recycles 0 hard 0 soft 0.15 temp 1 seqid 0.14 loss 2.12 dgram_cce 2.12 plddt 0.82 ptm 0.06 rmsd 1.03
# 46 models [4] recycles 0 hard 0 soft 0.15 temp 1 seqid 0.29 loss 2.33 dgram_cce 2.33 plddt 0.87 ptm 0.06 rmsd 0.57
# 47 models [3] recycles 0 hard 0 soft 0.16 temp 1 seqid 0.29 loss 2.04 dgram_cce 2.04 plddt 0.87 ptm 0.06 rmsd 0.69
# 48 models [0] recycles 0 hard 0 soft 0.16 temp 1 seqid 0.29 loss 1.76 dgram_cce 1.76 plddt 0.84 ptm 0.06 rmsd 0.47
# 49 models [3] recycles 0 hard 0 soft 0.16 temp 1 seqid 0.29 loss 1.69 dgram_cce 1.69 plddt 0.88 ptm 0.06 rmsd 0.53
# 50 models [2] recycles 0 hard 0 soft 0.17 temp 1 seqid 0.29 loss 1.86 dgram_cce 1.86 plddt 0.86 ptm 0.06 rmsd 0.87
# 51 models [0] recycles 0 hard 0 soft 0.17 temp 1 seqid 0.29 loss 2.14 dgram_cce 2.14 plddt 0.86 ptm 0.06 rmsd 0.49
# 52 models [1] recycles 0 hard 0 soft 0.17 temp 1 seqid 0.29 loss 1.82 dgram_cce 1.82 plddt 0.81 ptm 0.06 rmsd 0.77
# 53 models [2] recycles 0 hard 0 soft 0.18 temp 1 seqid 0.29 loss 1.85 dgram_cce 1.85 plddt 0.90 ptm 0.06 rmsd 0.65
# 54 models [1] recycles 0 hard 0 soft 0.18 temp 1 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.88 ptm 0.06 rmsd 0.56
# 55 models [4] recycles 0 hard 0 soft 0.18 temp 1 seqid 0.29 loss 1.78 dgram_cce 1.78 plddt 0.87 ptm 0.06 rmsd 0.58
# 56 models [0] recycles 0 hard 0 soft 0.19 temp 1 seqid 0.29 loss 1.61 dgram_cce 1.61 plddt 0.87 ptm 0.06 rmsd 0.47
# 57 models [4] recycles 0 hard 0 soft 0.19 temp 1 seqid 0.43 loss 1.66 dgram_cce 1.66 plddt 0.90 ptm 0.06 rmsd 0.51
# 58 models [0] recycles 0 hard 0 soft 0.19 temp 1 seqid 0.43 loss 1.60 dgram_cce 1.60 plddt 0.91 ptm 0.06 rmsd 0.41
# 59 models [4] recycles 0 hard 0 soft 0.20 temp 1 seqid 0.43 loss 1.71 dgram_cce 1.71 plddt 0.89 ptm 0.06 rmsd 0.42
# 60 models [0] recycles 0 hard 0 soft 0.20 temp 1 seqid 0.43 loss 1.60 dgram_cce 1.60 plddt 0.88 ptm 0.06 rmsd 0.41
# 61 models [3] recycles 0 hard 0 soft 0.20 temp 1 seqid 0.43 loss 1.69 dgram_cce 1.69 plddt 0.86 ptm 0.06 rmsd 0.54
# 62 models [3] recycles 0 hard 0 soft 0.21 temp 1 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.88 ptm 0.06 rmsd 0.43
# 63 models [1] recycles 0 hard 0 soft 0.21 temp 1 seqid 0.29 loss 1.79 dgram_cce 1.79 plddt 0.85 ptm 0.06 rmsd 0.42
# 64 models [2] recycles 0 hard 0 soft 0.21 temp 1 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.90 ptm 0.06 rmsd 0.63
# 65 models [2] recycles 0 hard 0 soft 0.22 temp 1 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.89 ptm 0.06 rmsd 0.44
# 66 models [3] recycles 0 hard 0 soft 0.22 temp 1 seqid 0.29 loss 1.75 dgram_cce 1.75 plddt 0.90 ptm 0.06 rmsd 0.60
# 67 models [4] recycles 0 hard 0 soft 0.22 temp 1 seqid 0.43 loss 1.69 dgram_cce 1.69 plddt 0.89 ptm 0.06 rmsd 0.36
# 68 models [2] recycles 0 hard 0 soft 0.23 temp 1 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.89 ptm 0.06 rmsd 0.42
# 69 models [3] recycles 0 hard 0 soft 0.23 temp 1 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.91 ptm 0.06 rmsd 0.46
# 70 models [2] recycles 0 hard 0 soft 0.23 temp 1 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.90 ptm 0.06 rmsd 0.25
# 71 models [2] recycles 0 hard 0 soft 0.24 temp 1 seqid 0.43 loss 1.60 dgram_cce 1.60 plddt 0.85 ptm 0.06 rmsd 0.39
# 72 models [2] recycles 0 hard 0 soft 0.24 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.91 ptm 0.06 rmsd 0.30
# 73 models [0] recycles 0 hard 0 soft 0.24 temp 1 seqid 0.29 loss 1.67 dgram_cce 1.67 plddt 0.91 ptm 0.06 rmsd 0.42
# 74 models [0] recycles 0 hard 0 soft 0.25 temp 1 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.88 ptm 0.06 rmsd 0.31
# 75 models [2] recycles 0 hard 0 soft 0.25 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.93 ptm 0.06 rmsd 0.38
# 76 models [3] recycles 0 hard 0 soft 0.25 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.90 ptm 0.06 rmsd 0.42
# 77 models [4] recycles 0 hard 0 soft 0.26 temp 1 seqid 0.43 loss 1.61 dgram_cce 1.61 plddt 0.92 ptm 0.06 rmsd 0.42
# 78 models [3] recycles 0 hard 0 soft 0.26 temp 1 seqid 0.43 loss 1.66 dgram_cce 1.66 plddt 0.91 ptm 0.06 rmsd 0.49
# 79 models [2] recycles 0 hard 0 soft 0.26 temp 1 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.93 ptm 0.06 rmsd 0.42
# 80 models [3] recycles 0 hard 0 soft 0.27 temp 1 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.91 ptm 0.06 rmsd 0.51
# 81 models [3] recycles 0 hard 0 soft 0.27 temp 1 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.90 ptm 0.06 rmsd 0.30
# 82 models [1] recycles 0 hard 0 soft 0.27 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.88 ptm 0.06 rmsd 0.36
# 83 models [4] recycles 0 hard 0 soft 0.28 temp 1 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.94 ptm 0.06 rmsd 0.39
# 84 models [4] recycles 0 hard 0 soft 0.28 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.93 ptm 0.06 rmsd 0.33
# 85 models [3] recycles 0 hard 0 soft 0.28 temp 1 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.93 ptm 0.06 rmsd 0.38
# 86 models [3] recycles 0 hard 0 soft 0.29 temp 1 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.89 ptm 0.06 rmsd 0.38
# 87 models [0] recycles 0 hard 0 soft 0.29 temp 1 seqid 0.29 loss 1.57 dgram_cce 1.57 plddt 0.85 ptm 0.06 rmsd 0.27
# 88 models [2] recycles 0 hard 0 soft 0.29 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.91 ptm 0.06 rmsd 0.38
# 89 models [4] recycles 0 hard 0 soft 0.30 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.91 ptm 0.06 rmsd 0.38
# 90 models [0] recycles 0 hard 0 soft 0.30 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.89 ptm 0.06 rmsd 0.32
# 91 models [1] recycles 0 hard 0 soft 0.30 temp 1 seqid 0.43 loss 1.75 dgram_cce 1.75 plddt 0.86 ptm 0.06 rmsd 0.37
# 92 models [4] recycles 0 hard 0 soft 0.31 temp 1 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.93 ptm 0.06 rmsd 0.45
# 93 models [3] recycles 0 hard 0 soft 0.31 temp 1 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.89 ptm 0.06 rmsd 0.40
# 94 models [2] recycles 0 hard 0 soft 0.31 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.91 ptm 0.06 rmsd 0.28
# 95 models [4] recycles 0 hard 0 soft 0.32 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.95 ptm 0.06 rmsd 0.33
# 96 models [1] recycles 0 hard 0 soft 0.32 temp 1 seqid 0.43 loss 1.60 dgram_cce 1.60 plddt 0.89 ptm 0.06 rmsd 0.36
# 97 models [4] recycles 0 hard 0 soft 0.32 temp 1 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.93 ptm 0.06 rmsd 0.41
# 98 models [3] recycles 0 hard 0 soft 0.33 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.92 ptm 0.06 rmsd 0.38
# 99 models [3] recycles 0 hard 0 soft 0.33 temp 1 seqid 0.29 loss 1.63 dgram_cce 1.63 plddt 0.87 ptm 0.06 rmsd 0.45
# 100 models [2] recycles 0 hard 0 soft 0.33 temp 1 seqid 0.43 loss 1.37 dgram_cce 1.37 plddt 0.91 ptm 0.06 rmsd 0.27
# 101 models [0] recycles 0 hard 0 soft 0.34 temp 1 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.91 ptm 0.06 rmsd 0.29
# 102 models [2] recycles 0 hard 0 soft 0.34 temp 1 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.87 ptm 0.06 rmsd 0.48
# 103 models [2] recycles 0 hard 0 soft 0.34 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.92 ptm 0.06 rmsd 0.37
# 104 models [2] recycles 0 hard 0 soft 0.35 temp 1 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.91 ptm 0.06 rmsd 0.38
# 105 models [4] recycles 0 hard 0 soft 0.35 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.95 ptm 0.07 rmsd 0.36
# 106 models [2] recycles 0 hard 0 soft 0.35 temp 1 seqid 0.29 loss 1.45 dgram_cce 1.45 plddt 0.87 ptm 0.06 rmsd 0.37
# 107 models [3] recycles 0 hard 0 soft 0.36 temp 1 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.06 rmsd 0.42
# 108 models [0] recycles 0 hard 0 soft 0.36 temp 1 seqid 0.29 loss 1.37 dgram_cce 1.37 plddt 0.92 ptm 0.06 rmsd 0.27
# 109 models [1] recycles 0 hard 0 soft 0.36 temp 1 seqid 0.43 loss 1.64 dgram_cce 1.64 plddt 0.88 ptm 0.06 rmsd 0.31
# 110 models [2] recycles 0 hard 0 soft 0.37 temp 1 seqid 0.43 loss 1.47 dgram_cce 1.47 plddt 0.91 ptm 0.06 rmsd 0.38
# 111 models [3] recycles 0 hard 0 soft 0.37 temp 1 seqid 0.29 loss 2.31 dgram_cce 2.31 plddt 0.63 ptm 0.05 rmsd 3.43
# 112 models [0] recycles 0 hard 0 soft 0.37 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.92 ptm 0.06 rmsd 0.42
# 113 models [3] recycles 0 hard 0 soft 0.38 temp 1 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.92 ptm 0.06 rmsd 0.39
# 114 models [0] recycles 0 hard 0 soft 0.38 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.31
# 115 models [0] recycles 0 hard 0 soft 0.38 temp 1 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.90 ptm 0.06 rmsd 0.38
# 116 models [1] recycles 0 hard 0 soft 0.39 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.37
# 117 models [0] recycles 0 hard 0 soft 0.39 temp 1 seqid 0.29 loss 1.36 dgram_cce 1.36 plddt 0.89 ptm 0.06 rmsd 0.31
# 118 models [0] recycles 0 hard 0 soft 0.39 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.90 ptm 0.07 rmsd 0.32
# 119 models [4] recycles 0 hard 0 soft 0.40 temp 1 seqid 0.29 loss 1.58 dgram_cce 1.58 plddt 0.92 ptm 0.06 rmsd 0.42
# 120 models [4] recycles 0 hard 0 soft 0.40 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.07 rmsd 0.37
# 121 models [2] recycles 0 hard 0 soft 0.40 temp 1 seqid 0.29 loss 1.60 dgram_cce 1.60 plddt 0.86 ptm 0.06 rmsd 0.49
# 122 models [2] recycles 0 hard 0 soft 0.41 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.88 ptm 0.06 rmsd 0.39
# 123 models [1] recycles 0 hard 0 soft 0.41 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.89 ptm 0.06 rmsd 0.34
# 124 models [0] recycles 0 hard 0 soft 0.41 temp 1 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.93 ptm 0.07 rmsd 0.29
# 125 models [4] recycles 0 hard 0 soft 0.42 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.92 ptm 0.07 rmsd 0.35
# 126 models [1] recycles 0 hard 0 soft 0.42 temp 1 seqid 0.29 loss 1.55 dgram_cce 1.55 plddt 0.89 ptm 0.06 rmsd 0.37
# 127 models [4] recycles 0 hard 0 soft 0.42 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.93 ptm 0.07 rmsd 0.36
# 128 models [1] recycles 0 hard 0 soft 0.43 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.84 ptm 0.06 rmsd 0.37
# 129 models [2] recycles 0 hard 0 soft 0.43 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.93 ptm 0.06 rmsd 0.37
# 130 models [0] recycles 0 hard 0 soft 0.43 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.92 ptm 0.07 rmsd 0.29
# 131 models [3] recycles 0 hard 0 soft 0.44 temp 1 seqid 0.29 loss 1.53 dgram_cce 1.53 plddt 0.89 ptm 0.06 rmsd 0.38
# 132 models [2] recycles 0 hard 0 soft 0.44 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.89 ptm 0.06 rmsd 0.35
# 133 models [0] recycles 0 hard 0 soft 0.44 temp 1 seqid 0.29 loss 1.35 dgram_cce 1.35 plddt 0.92 ptm 0.06 rmsd 0.38
# 134 models [3] recycles 0 hard 0 soft 0.45 temp 1 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.90 ptm 0.06 rmsd 0.46
# 135 models [4] recycles 0 hard 0 soft 0.45 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.94 ptm 0.06 rmsd 0.33
# 136 models [1] recycles 0 hard 0 soft 0.45 temp 1 seqid 0.29 loss 1.62 dgram_cce 1.62 plddt 0.88 ptm 0.06 rmsd 0.47
# 137 models [2] recycles 0 hard 0 soft 0.46 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.85 ptm 0.06 rmsd 0.40
# 138 models [0] recycles 0 hard 0 soft 0.46 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.91 ptm 0.06 rmsd 0.29
# 139 models [2] recycles 0 hard 0 soft 0.46 temp 1 seqid 0.29 loss 1.51 dgram_cce 1.51 plddt 0.89 ptm 0.06 rmsd 0.36
# 140 models [3] recycles 0 hard 0 soft 0.47 temp 1 seqid 0.29 loss 1.38 dgram_cce 1.38 plddt 0.92 ptm 0.06 rmsd 0.40
# 141 models [0] recycles 0 hard 0 soft 0.47 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.93 ptm 0.06 rmsd 0.32
# 142 models [4] recycles 0 hard 0 soft 0.47 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.93 ptm 0.07 rmsd 0.32
# 143 models [3] recycles 0 hard 0 soft 0.48 temp 1 seqid 0.29 loss 1.48 dgram_cce 1.48 plddt 0.90 ptm 0.06 rmsd 0.33
# 144 models [3] recycles 0 hard 0 soft 0.48 temp 1 seqid 0.29 loss 1.56 dgram_cce 1.56 plddt 0.90 ptm 0.06 rmsd 0.43
# 145 models [4] recycles 0 hard 0 soft 0.48 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.94 ptm 0.07 rmsd 0.43
# 146 models [3] recycles 0 hard 0 soft 0.49 temp 1 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.86 ptm 0.06 rmsd 0.35
# 147 models [3] recycles 0 hard 0 soft 0.49 temp 1 seqid 0.29 loss 1.52 dgram_cce 1.52 plddt 0.91 ptm 0.06 rmsd 0.34
# 148 models [1] recycles 0 hard 0 soft 0.49 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.89 ptm 0.06 rmsd 0.32
# 149 models [2] recycles 0 hard 0 soft 0.50 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.90 ptm 0.07 rmsd 0.37
# 150 models [2] recycles 0 hard 0 soft 0.50 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.92 ptm 0.07 rmsd 0.33
# 151 models [4] recycles 0 hard 0 soft 0.50 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.39
# 152 models [2] recycles 0 hard 0 soft 0.51 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.90 ptm 0.07 rmsd 0.24
# 153 models [4] recycles 0 hard 0 soft 0.51 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.94 ptm 0.07 rmsd 0.37
# 154 models [3] recycles 0 hard 0 soft 0.51 temp 1 seqid 0.29 loss 1.54 dgram_cce 1.54 plddt 0.91 ptm 0.06 rmsd 0.43
# 155 models [4] recycles 0 hard 0 soft 0.52 temp 1 seqid 0.29 loss 1.39 dgram_cce 1.39 plddt 0.95 ptm 0.07 rmsd 0.30
# 156 models [2] recycles 0 hard 0 soft 0.52 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.91 ptm 0.06 rmsd 0.32
# 157 models [3] recycles 0 hard 0 soft 0.52 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.93 ptm 0.06 rmsd 0.41
# 158 models [1] recycles 0 hard 0 soft 0.53 temp 1 seqid 0.43 loss 1.42 dgram_cce 1.42 plddt 0.88 ptm 0.06 rmsd 0.29
# 159 models [0] recycles 0 hard 0 soft 0.53 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.87 ptm 0.06 rmsd 0.33
# 160 models [0] recycles 0 hard 0 soft 0.53 temp 1 seqid 0.29 loss 1.38 dgram_cce 1.38 plddt 0.92 ptm 0.06 rmsd 0.33
# 161 models [1] recycles 0 hard 0 soft 0.54 temp 1 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.90 ptm 0.06 rmsd 0.38
# 162 models [1] recycles 0 hard 0 soft 0.54 temp 1 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.90 ptm 0.06 rmsd 0.33
# 163 models [1] recycles 0 hard 0 soft 0.54 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.92 ptm 0.06 rmsd 0.34
# 164 models [3] recycles 0 hard 0 soft 0.55 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.06 rmsd 0.33
# 165 models [3] recycles 0 hard 0 soft 0.55 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.91 ptm 0.06 rmsd 0.41
# 166 models [2] recycles 0 hard 0 soft 0.55 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.89 ptm 0.06 rmsd 0.36
# 167 models [4] recycles 0 hard 0 soft 0.56 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.92 ptm 0.06 rmsd 0.37
# 168 models [1] recycles 0 hard 0 soft 0.56 temp 1 seqid 0.29 loss 1.40 dgram_cce 1.40 plddt 0.91 ptm 0.06 rmsd 0.38
# 169 models [1] recycles 0 hard 0 soft 0.56 temp 1 seqid 0.43 loss 1.44 dgram_cce 1.44 plddt 0.94 ptm 0.07 rmsd 0.33
# 170 models [0] recycles 0 hard 0 soft 0.57 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.90 ptm 0.06 rmsd 0.39
# 171 models [3] recycles 0 hard 0 soft 0.57 temp 1 seqid 0.29 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.37
# 172 models [1] recycles 0 hard 0 soft 0.57 temp 1 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.88 ptm 0.06 rmsd 0.32
# 173 models [1] recycles 0 hard 0 soft 0.58 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.87 ptm 0.07 rmsd 0.33
# 174 models [0] recycles 0 hard 0 soft 0.58 temp 1 seqid 0.29 loss 1.47 dgram_cce 1.47 plddt 0.91 ptm 0.06 rmsd 0.38
# 175 models [3] recycles 0 hard 0 soft 0.58 temp 1 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.90 ptm 0.06 rmsd 0.46
# 176 models [0] recycles 0 hard 0 soft 0.59 temp 1 seqid 0.43 loss 1.42 dgram_cce 1.42 plddt 0.92 ptm 0.06 rmsd 0.35
# 177 models [0] recycles 0 hard 0 soft 0.59 temp 1 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.88 ptm 0.06 rmsd 0.40
# 178 models [4] recycles 0 hard 0 soft 0.59 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.92 ptm 0.06 rmsd 0.36
# 179 models [4] recycles 0 hard 0 soft 0.60 temp 1 seqid 0.29 loss 1.44 dgram_cce 1.44 plddt 0.90 ptm 0.06 rmsd 0.31
# 180 models [4] recycles 0 hard 0 soft 0.60 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.91 ptm 0.06 rmsd 0.42
# 181 models [1] recycles 0 hard 0 soft 0.60 temp 1 seqid 0.29 loss 1.41 dgram_cce 1.41 plddt 0.90 ptm 0.06 rmsd 0.34
# 182 models [2] recycles 0 hard 0 soft 0.61 temp 1 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.90 ptm 0.06 rmsd 0.31
# 183 models [4] recycles 0 hard 0 soft 0.61 temp 1 seqid 0.29 loss 1.49 dgram_cce 1.49 plddt 0.92 ptm 0.06 rmsd 0.39
# 184 models [0] recycles 0 hard 0 soft 0.61 temp 1 seqid 0.43 loss 1.37 dgram_cce 1.37 plddt 0.89 ptm 0.06 rmsd 0.33
# 185 models [3] recycles 0 hard 0 soft 0.62 temp 1 seqid 0.29 loss 1.67 dgram_cce 1.67 plddt 0.86 ptm 0.06 rmsd 0.57
# 186 models [4] recycles 0 hard 0 soft 0.62 temp 1 seqid 0.29 loss 1.46 dgram_cce 1.46 plddt 0.91 ptm 0.06 rmsd 0.36
# 187 models [0] recycles 0 hard 0 soft 0.62 temp 1 seqid 0.43 loss 1.41 dgram_cce 1.41 plddt 0.92 ptm 0.07 rmsd 0.38
# 188 models [0] recycles 0 hard 0 soft 0.63 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.90 ptm 0.06 rmsd 0.39
# 189 models [4] recycles 0 hard 0 soft 0.63 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.90 ptm 0.06 rmsd 0.43
# 190 models [4] recycles 0 hard 0 soft 0.63 temp 1 seqid 0.29 loss 1.38 dgram_cce 1.38 plddt 0.93 ptm 0.06 rmsd 0.28
# 191 models [4] recycles 0 hard 0 soft 0.64 temp 1 seqid 0.29 loss 1.59 dgram_cce 1.59 plddt 0.93 ptm 0.06 rmsd 0.33
# 192 models [4] recycles 0 hard 0 soft 0.64 temp 1 seqid 0.29 loss 1.34 dgram_cce 1.34 plddt 0.92 ptm 0.06 rmsd 0.28
# 193 models [1] recycles 0 hard 0 soft 0.64 temp 1 seqid 0.29 loss 1.42 dgram_cce 1.42 plddt 0.93 ptm 0.06 rmsd 0.30
# 194 models [0] recycles 0 hard 0 soft 0.65 temp 1 seqid 0.43 loss 1.32 dgram_cce 1.32 plddt 0.92 ptm 0.07 rmsd 0.28
# 195 models [4] recycles 0 hard 0 soft 0.65 temp 1 seqid 0.29 loss 1.43 dgram_cce 1.43 plddt 0.87 ptm 0.07 rmsd 0.39
# 196 models [4] recycles 0 hard 0 soft 0.65 temp 1 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.06 rmsd 0.37
# 197 models [0] recycles 0 hard 0 soft 0.66 temp 1 seqid 0.29 loss 1.32 dgram_cce 1.32 plddt 0.91 ptm 0.07 rmsd 0.39
# 198 models [4] recycles 0 hard 0 soft 0.66 temp 1 seqid 0.43 loss 1.37 dgram_cce 1.37 plddt 0.95 ptm 0.07 rmsd 0.39
# 199 models [4] recycles 0 hard 0 soft 0.66 temp 1 seqid 0.57 loss 1.54 dgram_cce 1.54 plddt 0.94 ptm 0.06 rmsd 0.29
# 200 models [0] recycles 0 hard 0 soft 0.67 temp 1 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.94 ptm 0.06 rmsd 0.42
# 201 models [1] recycles 0 hard 0 soft 0.67 temp 1 seqid 0.29 loss 1.37 dgram_cce 1.37 plddt 0.90 ptm 0.06 rmsd 0.30
# 202 models [1] recycles 0 hard 0 soft 0.67 temp 1 seqid 0.43 loss 1.32 dgram_cce 1.32 plddt 0.92 ptm 0.07 rmsd 0.32
# 203 models [0] recycles 0 hard 0 soft 0.68 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.88 ptm 0.06 rmsd 0.36
# 204 models [2] recycles 0 hard 0 soft 0.68 temp 1 seqid 0.43 loss 1.44 dgram_cce 1.44 plddt 0.89 ptm 0.06 rmsd 0.37
# 205 models [3] recycles 0 hard 0 soft 0.68 temp 1 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.93 ptm 0.06 rmsd 0.50
# 206 models [3] recycles 0 hard 0 soft 0.69 temp 1 seqid 0.43 loss 1.39 dgram_cce 1.39 plddt 0.93 ptm 0.06 rmsd 0.39
# 207 models [3] recycles 0 hard 0 soft 0.69 temp 1 seqid 0.43 loss 1.90 dgram_cce 1.90 plddt 0.82 ptm 0.06 rmsd 0.45
# 208 models [2] recycles 0 hard 0 soft 0.69 temp 1 seqid 0.43 loss 1.34 dgram_cce 1.34 plddt 0.91 ptm 0.06 rmsd 0.30
# 209 models [2] recycles 0 hard 0 soft 0.70 temp 1 seqid 0.43 loss 1.47 dgram_cce 1.47 plddt 0.89 ptm 0.06 rmsd 0.45
# 210 models [2] recycles 0 hard 0 soft 0.70 temp 1 seqid 0.43 loss 1.39 dgram_cce 1.39 plddt 0.91 ptm 0.06 rmsd 0.33
# 211 models [2] recycles 0 hard 0 soft 0.70 temp 1 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.92 ptm 0.06 rmsd 0.41
# 212 models [3] recycles 0 hard 0 soft 0.71 temp 1 seqid 0.57 loss 1.44 dgram_cce 1.44 plddt 0.91 ptm 0.06 rmsd 0.44
# 213 models [1] recycles 0 hard 0 soft 0.71 temp 1 seqid 0.43 loss 1.27 dgram_cce 1.27 plddt 0.92 ptm 0.07 rmsd 0.32
# 214 models [4] recycles 0 hard 0 soft 0.71 temp 1 seqid 0.57 loss 1.46 dgram_cce 1.46 plddt 0.93 ptm 0.06 rmsd 0.38
# 215 models [0] recycles 0 hard 0 soft 0.72 temp 1 seqid 0.57 loss 1.33 dgram_cce 1.33 plddt 0.93 ptm 0.07 rmsd 0.43
# 216 models [4] recycles 0 hard 0 soft 0.72 temp 1 seqid 0.57 loss 1.53 dgram_cce 1.53 plddt 0.94 ptm 0.06 rmsd 0.34
# 217 models [1] recycles 0 hard 0 soft 0.72 temp 1 seqid 0.57 loss 1.23 dgram_cce 1.23 plddt 0.91 ptm 0.07 rmsd 0.38
# 218 models [0] recycles 0 hard 0 soft 0.73 temp 1 seqid 0.57 loss 1.28 dgram_cce 1.28 plddt 0.95 ptm 0.07 rmsd 0.45
# 219 models [4] recycles 0 hard 0 soft 0.73 temp 1 seqid 0.57 loss 1.43 dgram_cce 1.43 plddt 0.92 ptm 0.06 rmsd 0.32
# 220 models [3] recycles 0 hard 0 soft 0.73 temp 1 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.93 ptm 0.06 rmsd 0.48
# 221 models [2] recycles 0 hard 0 soft 0.74 temp 1 seqid 0.43 loss 1.38 dgram_cce 1.38 plddt 0.92 ptm 0.07 rmsd 0.33
# 222 models [0] recycles 0 hard 0 soft 0.74 temp 1 seqid 0.57 loss 1.43 dgram_cce 1.43 plddt 0.94 ptm 0.07 rmsd 0.42
# 223 models [1] recycles 0 hard 0 soft 0.74 temp 1 seqid 0.43 loss 1.24 dgram_cce 1.24 plddt 0.92 ptm 0.07 rmsd 0.32
# 224 models [3] recycles 0 hard 0 soft 0.75 temp 1 seqid 0.57 loss 1.57 dgram_cce 1.57 plddt 0.93 ptm 0.06 rmsd 0.43
# 225 models [1] recycles 0 hard 0 soft 0.75 temp 1 seqid 0.57 loss 1.34 dgram_cce 1.34 plddt 0.92 ptm 0.06 rmsd 0.36
# 226 models [0] recycles 0 hard 0 soft 0.75 temp 1 seqid 0.57 loss 1.32 dgram_cce 1.32 plddt 0.91 ptm 0.06 rmsd 0.41
# 227 models [0] recycles 0 hard 0 soft 0.76 temp 1 seqid 0.57 loss 1.37 dgram_cce 1.37 plddt 0.91 ptm 0.06 rmsd 0.49
# 228 models [3] recycles 0 hard 0 soft 0.76 temp 1 seqid 0.57 loss 1.52 dgram_cce 1.52 plddt 0.90 ptm 0.06 rmsd 0.44
# 229 models [0] recycles 0 hard 0 soft 0.76 temp 1 seqid 0.57 loss 1.31 dgram_cce 1.31 plddt 0.94 ptm 0.07 rmsd 0.47
# 230 models [3] recycles 0 hard 0 soft 0.77 temp 1 seqid 0.57 loss 1.55 dgram_cce 1.55 plddt 0.91 ptm 0.06 rmsd 0.51
# 231 models [2] recycles 0 hard 0 soft 0.77 temp 1 seqid 0.57 loss 1.46 dgram_cce 1.46 plddt 0.85 ptm 0.06 rmsd 0.35
# 232 models [1] recycles 0 hard 0 soft 0.77 temp 1 seqid 0.57 loss 1.35 dgram_cce 1.35 plddt 0.91 ptm 0.07 rmsd 0.36
# 233 models [2] recycles 0 hard 0 soft 0.78 temp 1 seqid 0.57 loss 1.41 dgram_cce 1.41 plddt 0.90 ptm 0.06 rmsd 0.36
# 234 models [1] recycles 0 hard 0 soft 0.78 temp 1 seqid 0.43 loss 1.29 dgram_cce 1.29 plddt 0.92 ptm 0.07 rmsd 0.33
# 235 models [0] recycles 0 hard 0 soft 0.78 temp 1 seqid 0.43 loss 1.34 dgram_cce 1.34 plddt 0.91 ptm 0.07 rmsd 0.36
# 236 models [1] recycles 0 hard 0 soft 0.79 temp 1 seqid 0.43 loss 1.34 dgram_cce 1.34 plddt 0.93 ptm 0.07 rmsd 0.39
# 237 models [0] recycles 0 hard 0 soft 0.79 temp 1 seqid 0.57 loss 1.26 dgram_cce 1.26 plddt 0.91 ptm 0.06 rmsd 0.40
# 238 models [1] recycles 0 hard 0 soft 0.79 temp 1 seqid 0.57 loss 1.34 dgram_cce 1.34 plddt 0.90 ptm 0.06 rmsd 0.41
# 239 models [1] recycles 0 hard 0 soft 0.80 temp 1 seqid 0.57 loss 1.41 dgram_cce 1.41 plddt 0.88 ptm 0.06 rmsd 0.42
# 240 models [0] recycles 0 hard 0 soft 0.80 temp 1 seqid 0.57 loss 1.34 dgram_cce 1.34 plddt 0.93 ptm 0.06 rmsd 0.39
# 241 models [2] recycles 0 hard 0 soft 0.80 temp 1 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.91 ptm 0.06 rmsd 0.42
# 242 models [1] recycles 0 hard 0 soft 0.81 temp 1 seqid 0.43 loss 1.41 dgram_cce 1.41 plddt 0.92 ptm 0.07 rmsd 0.34
# 243 models [2] recycles 0 hard 0 soft 0.81 temp 1 seqid 0.43 loss 1.40 dgram_cce 1.40 plddt 0.90 ptm 0.06 rmsd 0.35
# 244 models [3] recycles 0 hard 0 soft 0.81 temp 1 seqid 0.57 loss 1.43 dgram_cce 1.43 plddt 0.91 ptm 0.06 rmsd 0.44
# 245 models [2] recycles 0 hard 0 soft 0.82 temp 1 seqid 0.43 loss 1.29 dgram_cce 1.29 plddt 0.93 ptm 0.06 rmsd 0.42
# 246 models [4] recycles 0 hard 0 soft 0.82 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.90 ptm 0.06 rmsd 0.41
# 247 models [4] recycles 0 hard 0 soft 0.82 temp 1 seqid 0.57 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.06 rmsd 0.41
# 248 models [4] recycles 0 hard 0 soft 0.83 temp 1 seqid 0.57 loss 1.54 dgram_cce 1.54 plddt 0.90 ptm 0.06 rmsd 0.46
# 249 models [2] recycles 0 hard 0 soft 0.83 temp 1 seqid 0.57 loss 1.60 dgram_cce 1.60 plddt 0.93 ptm 0.07 rmsd 0.36
# 250 models [0] recycles 0 hard 0 soft 0.83 temp 1 seqid 0.57 loss 1.30 dgram_cce 1.30 plddt 0.91 ptm 0.07 rmsd 0.35
# 251 models [1] recycles 0 hard 0 soft 0.84 temp 1 seqid 0.57 loss 1.41 dgram_cce 1.41 plddt 0.89 ptm 0.06 rmsd 0.38
# 252 models [3] recycles 0 hard 0 soft 0.84 temp 1 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.90 ptm 0.06 rmsd 0.51
# 253 models [3] recycles 0 hard 0 soft 0.84 temp 1 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.90 ptm 0.06 rmsd 0.48
# 254 models [4] recycles 0 hard 0 soft 0.85 temp 1 seqid 0.57 loss 1.55 dgram_cce 1.55 plddt 0.91 ptm 0.06 rmsd 0.35
# 255 models [4] recycles 0 hard 0 soft 0.85 temp 1 seqid 0.57 loss 1.41 dgram_cce 1.41 plddt 0.91 ptm 0.07 rmsd 0.38
# 256 models [0] recycles 0 hard 0 soft 0.85 temp 1 seqid 0.43 loss 1.41 dgram_cce 1.41 plddt 0.91 ptm 0.06 rmsd 0.31
# 257 models [4] recycles 0 hard 0 soft 0.86 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.92 ptm 0.07 rmsd 0.42
# 258 models [3] recycles 0 hard 0 soft 0.86 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.91 ptm 0.06 rmsd 0.55
# 259 models [1] recycles 0 hard 0 soft 0.86 temp 1 seqid 0.43 loss 1.41 dgram_cce 1.41 plddt 0.94 ptm 0.07 rmsd 0.36
# 260 models [1] recycles 0 hard 0 soft 0.87 temp 1 seqid 0.43 loss 1.25 dgram_cce 1.25 plddt 0.87 ptm 0.06 rmsd 0.37
# 261 models [4] recycles 0 hard 0 soft 0.87 temp 1 seqid 0.57 loss 1.55 dgram_cce 1.55 plddt 0.91 ptm 0.06 rmsd 0.39
# 262 models [3] recycles 0 hard 0 soft 0.87 temp 1 seqid 0.57 loss 1.64 dgram_cce 1.64 plddt 0.88 ptm 0.06 rmsd 0.47
# 263 models [1] recycles 0 hard 0 soft 0.88 temp 1 seqid 0.57 loss 1.42 dgram_cce 1.42 plddt 0.89 ptm 0.06 rmsd 0.43
# 264 models [3] recycles 0 hard 0 soft 0.88 temp 1 seqid 0.57 loss 1.49 dgram_cce 1.49 plddt 0.90 ptm 0.06 rmsd 0.39
# 265 models [0] recycles 0 hard 0 soft 0.88 temp 1 seqid 0.57 loss 1.45 dgram_cce 1.45 plddt 0.91 ptm 0.06 rmsd 0.27
# 266 models [0] recycles 0 hard 0 soft 0.89 temp 1 seqid 0.57 loss 1.41 dgram_cce 1.41 plddt 0.93 ptm 0.07 rmsd 0.40
# 267 models [1] recycles 0 hard 0 soft 0.89 temp 1 seqid 0.57 loss 1.35 dgram_cce 1.35 plddt 0.93 ptm 0.07 rmsd 0.43
# 268 models [3] recycles 0 hard 0 soft 0.89 temp 1 seqid 0.57 loss 1.50 dgram_cce 1.50 plddt 0.93 ptm 0.06 rmsd 0.35
# 269 models [4] recycles 0 hard 0 soft 0.90 temp 1 seqid 0.57 loss 1.42 dgram_cce 1.42 plddt 0.92 ptm 0.06 rmsd 0.23
# 270 models [2] recycles 0 hard 0 soft 0.90 temp 1 seqid 0.43 loss 1.65 dgram_cce 1.65 plddt 0.88 ptm 0.06 rmsd 0.45
# 271 models [3] recycles 0 hard 0 soft 0.90 temp 1 seqid 0.57 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.55
# 272 models [2] recycles 0 hard 0 soft 0.91 temp 1 seqid 0.57 loss 1.31 dgram_cce 1.31 plddt 0.92 ptm 0.07 rmsd 0.31
# 273 models [0] recycles 0 hard 0 soft 0.91 temp 1 seqid 0.43 loss 1.39 dgram_cce 1.39 plddt 0.89 ptm 0.06 rmsd 0.33
# 274 models [4] recycles 0 hard 0 soft 0.91 temp 1 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.91 ptm 0.06 rmsd 0.43
# 275 models [4] recycles 0 hard 0 soft 0.92 temp 1 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.89 ptm 0.06 rmsd 0.33
# 276 models [2] recycles 0 hard 0 soft 0.92 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.88 ptm 0.06 rmsd 0.50
# 277 models [0] recycles 0 hard 0 soft 0.92 temp 1 seqid 0.43 loss 1.41 dgram_cce 1.41 plddt 0.92 ptm 0.07 rmsd 0.36
# 278 models [3] recycles 0 hard 0 soft 0.93 temp 1 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.89 ptm 0.06 rmsd 0.53
# 279 models [0] recycles 0 hard 0 soft 0.93 temp 1 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.89 ptm 0.06 rmsd 0.20
# 280 models [3] recycles 0 hard 0 soft 0.93 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.88 ptm 0.06 rmsd 0.34
# 281 models [2] recycles 0 hard 0 soft 0.94 temp 1 seqid 0.43 loss 1.42 dgram_cce 1.42 plddt 0.86 ptm 0.06 rmsd 0.35
# 282 models [1] recycles 0 hard 0 soft 0.94 temp 1 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.91 ptm 0.07 rmsd 0.42
# 283 models [3] recycles 0 hard 0 soft 0.94 temp 1 seqid 0.43 loss 1.40 dgram_cce 1.40 plddt 0.92 ptm 0.06 rmsd 0.39
# 284 models [2] recycles 0 hard 0 soft 0.95 temp 1 seqid 0.43 loss 1.61 dgram_cce 1.61 plddt 0.83 ptm 0.06 rmsd 0.24
# 285 models [0] recycles 0 hard 0 soft 0.95 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.91 ptm 0.06 rmsd 0.44
# 286 models [2] recycles 0 hard 0 soft 0.95 temp 1 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.88 ptm 0.06 rmsd 0.38
# 287 models [3] recycles 0 hard 0 soft 0.96 temp 1 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.93 ptm 0.06 rmsd 0.56
# 288 models [4] recycles 0 hard 0 soft 0.96 temp 1 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.92 ptm 0.06 rmsd 0.35
# 289 models [1] recycles 0 hard 0 soft 0.96 temp 1 seqid 0.43 loss 1.35 dgram_cce 1.35 plddt 0.91 ptm 0.06 rmsd 0.38
# 290 models [1] recycles 0 hard 0 soft 0.97 temp 1 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.87 ptm 0.07 rmsd 0.50
# 291 models [4] recycles 0 hard 0 soft 0.97 temp 1 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.92 ptm 0.06 rmsd 0.40
# 292 models [3] recycles 0 hard 0 soft 0.97 temp 1 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.94 ptm 0.06 rmsd 0.44
# 293 models [1] recycles 0 hard 0 soft 0.98 temp 1 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.88 ptm 0.06 rmsd 0.42
# 294 models [0] recycles 0 hard 0 soft 0.98 temp 1 seqid 0.43 loss 1.61 dgram_cce 1.61 plddt 0.91 ptm 0.06 rmsd 0.34
# 295 models [0] recycles 0 hard 0 soft 0.98 temp 1 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.92 ptm 0.06 rmsd 0.47
# 296 models [1] recycles 0 hard 0 soft 0.99 temp 1 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.91 ptm 0.06 rmsd 0.32
# 297 models [0] recycles 0 hard 0 soft 0.99 temp 1 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.91 ptm 0.06 rmsd 0.44
# 298 models [2] recycles 0 hard 0 soft 0.99 temp 1 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.92 ptm 0.06 rmsd 0.48
# 299 models [1] recycles 0 hard 0 soft 1.00 temp 1 seqid 0.43 loss 1.63 dgram_cce 1.63 plddt 0.88 ptm 0.06 rmsd 0.50
# 300 models [2] recycles 0 hard 0 soft 1 temp 1 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.89 ptm 0.06 rmsd 0.45
# Stage 2: running (soft → hard)
# 301 models [0] recycles 0 hard 0 soft 1 temp 0.98 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.91 ptm 0.07 rmsd 0.50
# 302 models [0] recycles 0 hard 0 soft 1 temp 0.96 seqid 0.43 loss 1.40 dgram_cce 1.40 plddt 0.92 ptm 0.07 rmsd 0.33
# 303 models [4] recycles 0 hard 0 soft 1 temp 0.94 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.91 ptm 0.06 rmsd 0.39
# 304 models [4] recycles 0 hard 0 soft 1 temp 0.92 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.94 ptm 0.06 rmsd 0.41
# 305 models [4] recycles 0 hard 0 soft 1 temp 0.90 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.94 ptm 0.07 rmsd 0.40
# 306 models [2] recycles 0 hard 0 soft 1 temp 0.88 seqid 0.43 loss 1.63 dgram_cce 1.63 plddt 0.93 ptm 0.06 rmsd 0.37
# 307 models [0] recycles 0 hard 0 soft 1 temp 0.87 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.90 ptm 0.06 rmsd 0.46
# 308 models [1] recycles 0 hard 0 soft 1 temp 0.85 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.90 ptm 0.06 rmsd 0.47
# 309 models [1] recycles 0 hard 0 soft 1 temp 0.83 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.92 ptm 0.06 rmsd 0.40
# 310 models [2] recycles 0 hard 0 soft 1 temp 0.81 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.94 ptm 0.06 rmsd 0.45
# 311 models [1] recycles 0 hard 0 soft 1 temp 0.79 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.90 ptm 0.07 rmsd 0.42
# 312 models [1] recycles 0 hard 0 soft 1 temp 0.78 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.91 ptm 0.06 rmsd 0.48
# 313 models [0] recycles 0 hard 0 soft 1 temp 0.76 seqid 0.43 loss 1.40 dgram_cce 1.40 plddt 0.94 ptm 0.07 rmsd 0.23
# 314 models [1] recycles 0 hard 0 soft 1 temp 0.74 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.87 ptm 0.06 rmsd 0.47
# 315 models [0] recycles 0 hard 0 soft 1 temp 0.73 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.93 ptm 0.07 rmsd 0.49
# 316 models [1] recycles 0 hard 0 soft 1 temp 0.71 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.88 ptm 0.06 rmsd 0.47
# 317 models [4] recycles 0 hard 0 soft 1 temp 0.69 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.73
# 318 models [3] recycles 0 hard 0 soft 1 temp 0.68 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.92 ptm 0.06 rmsd 0.47
# 319 models [0] recycles 0 hard 0 soft 1 temp 0.66 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.93 ptm 0.07 rmsd 0.36
# 320 models [2] recycles 0 hard 0 soft 1 temp 0.64 seqid 0.43 loss 1.65 dgram_cce 1.65 plddt 0.88 ptm 0.09 rmsd 0.45
# 321 models [0] recycles 0 hard 0 soft 1 temp 0.63 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.06 rmsd 0.41
# 322 models [1] recycles 0 hard 0 soft 1 temp 0.61 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.88 ptm 0.06 rmsd 0.46
# 323 models [2] recycles 0 hard 0 soft 1 temp 0.60 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.92 ptm 0.06 rmsd 0.42
# 324 models [4] recycles 0 hard 0 soft 1 temp 0.58 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.93 ptm 0.06 rmsd 0.45
# 325 models [3] recycles 0 hard 0 soft 1 temp 0.57 seqid 0.43 loss 1.64 dgram_cce 1.64 plddt 0.91 ptm 0.06 rmsd 0.55
# 326 models [4] recycles 0 hard 0 soft 1 temp 0.55 seqid 0.43 loss 1.66 dgram_cce 1.66 plddt 0.93 ptm 0.07 rmsd 0.49
# 327 models [1] recycles 0 hard 0 soft 1 temp 0.54 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.93 ptm 0.07 rmsd 0.39
# 328 models [1] recycles 0 hard 0 soft 1 temp 0.52 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.91 ptm 0.07 rmsd 0.38
# 329 models [2] recycles 0 hard 0 soft 1 temp 0.51 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.91 ptm 0.06 rmsd 0.35
# 330 models [4] recycles 0 hard 0 soft 1 temp 0.50 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.92 ptm 0.06 rmsd 0.39
# 331 models [3] recycles 0 hard 0 soft 1 temp 0.48 seqid 0.43 loss 1.71 dgram_cce 1.71 plddt 0.69 ptm 0.06 rmsd 1.63
# 332 models [4] recycles 0 hard 0 soft 1 temp 0.47 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.93 ptm 0.06 rmsd 0.36
# 333 models [3] recycles 0 hard 0 soft 1 temp 0.45 seqid 0.43 loss 1.67 dgram_cce 1.67 plddt 0.87 ptm 0.06 rmsd 0.46
# 334 models [0] recycles 0 hard 0 soft 1 temp 0.44 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.87 ptm 0.06 rmsd 0.31
# 335 models [2] recycles 0 hard 0 soft 1 temp 0.43 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.91 ptm 0.06 rmsd 0.29
# 336 models [3] recycles 0 hard 0 soft 1 temp 0.42 seqid 0.43 loss 1.78 dgram_cce 1.78 plddt 0.80 ptm 0.06 rmsd 0.64
# 337 models [4] recycles 0 hard 0 soft 1 temp 0.40 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.89 ptm 0.06 rmsd 0.44
# 338 models [4] recycles 0 hard 0 soft 1 temp 0.39 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.91 ptm 0.06 rmsd 0.42
# 339 models [3] recycles 0 hard 0 soft 1 temp 0.38 seqid 0.43 loss 1.67 dgram_cce 1.67 plddt 0.93 ptm 0.06 rmsd 0.42
# 340 models [2] recycles 0 hard 0 soft 1 temp 0.37 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.90 ptm 0.06 rmsd 0.49
# 341 models [2] recycles 0 hard 0 soft 1 temp 0.35 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.86 ptm 0.06 rmsd 0.38
# 342 models [1] recycles 0 hard 0 soft 1 temp 0.34 seqid 0.43 loss 1.65 dgram_cce 1.65 plddt 0.88 ptm 0.07 rmsd 0.43
# 343 models [2] recycles 0 hard 0 soft 1 temp 0.33 seqid 0.43 loss 1.47 dgram_cce 1.47 plddt 0.91 ptm 0.06 rmsd 0.33
# 344 models [0] recycles 0 hard 0 soft 1 temp 0.32 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.92 ptm 0.07 rmsd 0.32
# 345 models [2] recycles 0 hard 0 soft 1 temp 0.31 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.92 ptm 0.06 rmsd 0.55
# 346 models [4] recycles 0 hard 0 soft 1 temp 0.30 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.93 ptm 0.06 rmsd 0.49
# 347 models [2] recycles 0 hard 0 soft 1 temp 0.29 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.93 ptm 0.07 rmsd 0.33
# 348 models [3] recycles 0 hard 0 soft 1 temp 0.28 seqid 0.43 loss 1.69 dgram_cce 1.69 plddt 0.93 ptm 0.06 rmsd 0.61
# 349 models [1] recycles 0 hard 0 soft 1 temp 0.27 seqid 0.43 loss 1.62 dgram_cce 1.62 plddt 0.90 ptm 0.07 rmsd 0.37
# 350 models [4] recycles 0 hard 0 soft 1 temp 0.26 seqid 0.43 loss 1.69 dgram_cce 1.69 plddt 0.92 ptm 0.06 rmsd 0.55
# 351 models [1] recycles 0 hard 0 soft 1 temp 0.25 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.91 ptm 0.06 rmsd 0.38
# 352 models [2] recycles 0 hard 0 soft 1 temp 0.24 seqid 0.43 loss 1.50 dgram_cce 1.50 plddt 0.93 ptm 0.07 rmsd 0.42
# 353 models [2] recycles 0 hard 0 soft 1 temp 0.23 seqid 0.43 loss 1.58 dgram_cce 1.58 plddt 0.91 ptm 0.06 rmsd 0.40
# 354 models [2] recycles 0 hard 0 soft 1 temp 0.22 seqid 0.43 loss 1.35 dgram_cce 1.35 plddt 0.90 ptm 0.06 rmsd 0.29
# 355 models [0] recycles 0 hard 0 soft 1 temp 0.21 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.91 ptm 0.07 rmsd 0.38
# 356 models [4] recycles 0 hard 0 soft 1 temp 0.20 seqid 0.43 loss 1.64 dgram_cce 1.64 plddt 0.95 ptm 0.06 rmsd 0.42
# 357 models [2] recycles 0 hard 0 soft 1 temp 0.19 seqid 0.43 loss 1.47 dgram_cce 1.47 plddt 0.94 ptm 0.07 rmsd 0.40
# 358 models [1] recycles 0 hard 0 soft 1 temp 0.18 seqid 0.43 loss 1.62 dgram_cce 1.62 plddt 0.85 ptm 0.06 rmsd 0.45
# 359 models [2] recycles 0 hard 0 soft 1 temp 0.18 seqid 0.43 loss 1.65 dgram_cce 1.65 plddt 0.87 ptm 0.06 rmsd 0.51
# 360 models [2] recycles 0 hard 0 soft 1 temp 0.17 seqid 0.43 loss 1.64 dgram_cce 1.64 plddt 0.92 ptm 0.06 rmsd 0.41
# 361 models [4] recycles 0 hard 0 soft 1 temp 0.16 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.93 ptm 0.07 rmsd 0.32
# 362 models [2] recycles 0 hard 0 soft 1 temp 0.15 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.87 ptm 0.06 rmsd 0.37
# 363 models [4] recycles 0 hard 0 soft 1 temp 0.15 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.93 ptm 0.06 rmsd 0.38
# 364 models [2] recycles 0 hard 0 soft 1 temp 0.14 seqid 0.43 loss 1.59 dgram_cce 1.59 plddt 0.92 ptm 0.07 rmsd 0.36
# 365 models [0] recycles 0 hard 0 soft 1 temp 0.13 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.88 ptm 0.06 rmsd 0.30
# 366 models [0] recycles 0 hard 0 soft 1 temp 0.12 seqid 0.43 loss 1.43 dgram_cce 1.43 plddt 0.93 ptm 0.07 rmsd 0.39
# 367 models [3] recycles 0 hard 0 soft 1 temp 0.12 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.92 ptm 0.06 rmsd 0.50
# 368 models [3] recycles 0 hard 0 soft 1 temp 0.11 seqid 0.43 loss 1.63 dgram_cce 1.63 plddt 0.87 ptm 0.06 rmsd 0.35
# 369 models [0] recycles 0 hard 0 soft 1 temp 0.11 seqid 0.43 loss 1.48 dgram_cce 1.48 plddt 0.91 ptm 0.06 rmsd 0.32
# 370 models [0] recycles 0 hard 0 soft 1 temp 0.10 seqid 0.43 loss 1.60 dgram_cce 1.60 plddt 0.88 ptm 0.06 rmsd 0.30
# 371 models [3] recycles 0 hard 0 soft 1 temp 0.09 seqid 0.43 loss 1.61 dgram_cce 1.61 plddt 0.88 ptm 0.06 rmsd 0.33
# 372 models [4] recycles 0 hard 0 soft 1 temp 0.09 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.87 ptm 0.06 rmsd 0.35
# 373 models [0] recycles 0 hard 0 soft 1 temp 0.08 seqid 0.43 loss 1.46 dgram_cce 1.46 plddt 0.94 ptm 0.07 rmsd 0.39
# 374 models [2] recycles 0 hard 0 soft 1 temp 0.08 seqid 0.43 loss 1.57 dgram_cce 1.57 plddt 0.90 ptm 0.06 rmsd 0.44
# 375 models [3] recycles 0 hard 0 soft 1 temp 0.07 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.92 ptm 0.06 rmsd 0.60
# 376 models [0] recycles 0 hard 0 soft 1 temp 0.07 seqid 0.43 loss 1.40 dgram_cce 1.40 plddt 0.88 ptm 0.07 rmsd 0.25
# 377 models [0] recycles 0 hard 0 soft 1 temp 0.06 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.92 ptm 0.07 rmsd 0.35
# 378 models [2] recycles 0 hard 0 soft 1 temp 0.06 seqid 0.43 loss 1.60 dgram_cce 1.60 plddt 0.88 ptm 0.06 rmsd 0.34
# 379 models [1] recycles 0 hard 0 soft 1 temp 0.05 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.91 ptm 0.07 rmsd 0.43
# 380 models [3] recycles 0 hard 0 soft 1 temp 0.05 seqid 0.43 loss 1.76 dgram_cce 1.76 plddt 0.89 ptm 0.06 rmsd 0.48
# 381 models [1] recycles 0 hard 0 soft 1 temp 0.05 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.87 ptm 0.06 rmsd 0.49
# 382 models [4] recycles 0 hard 0 soft 1 temp 0.04 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.91 ptm 0.07 rmsd 0.36
# 383 models [4] recycles 0 hard 0 soft 1 temp 0.04 seqid 0.43 loss 1.62 dgram_cce 1.62 plddt 0.90 ptm 0.07 rmsd 0.47
# 384 models [4] recycles 0 hard 0 soft 1 temp 0.04 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.88 ptm 0.07 rmsd 0.62
# 385 models [0] recycles 0 hard 0 soft 1 temp 0.03 seqid 0.43 loss 1.45 dgram_cce 1.45 plddt 0.93 ptm 0.07 rmsd 0.32
# 386 models [2] recycles 0 hard 0 soft 1 temp 0.03 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.89 ptm 0.06 rmsd 0.33
# 387 models [4] recycles 0 hard 0 soft 1 temp 0.03 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.92 ptm 0.07 rmsd 0.41
# 388 models [1] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.43 loss 1.55 dgram_cce 1.55 plddt 0.92 ptm 0.06 rmsd 0.44
# 389 models [4] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.92 ptm 0.07 rmsd 0.50
# 390 models [1] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.43 loss 1.52 dgram_cce 1.52 plddt 0.89 ptm 0.07 rmsd 0.35
# 391 models [2] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.84 ptm 0.07 rmsd 0.32
# 392 models [0] recycles 0 hard 0 soft 1 temp 0.02 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.92 ptm 0.06 rmsd 0.37
# 393 models [2] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.64 dgram_cce 1.64 plddt 0.91 ptm 0.07 rmsd 0.43
# 394 models [1] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.44 dgram_cce 1.44 plddt 0.88 ptm 0.07 rmsd 0.25
# 395 models [4] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.92 ptm 0.06 rmsd 0.48
# 396 models [4] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.53 dgram_cce 1.53 plddt 0.92 ptm 0.07 rmsd 0.35
# 397 models [4] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.56 dgram_cce 1.56 plddt 0.91 ptm 0.07 rmsd 0.47
# 398 models [1] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.70 dgram_cce 1.70 plddt 0.92 ptm 0.06 rmsd 0.45
# 399 models [2] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.66 dgram_cce 1.66 plddt 0.92 ptm 0.06 rmsd 0.40
# 400 models [1] recycles 0 hard 0 soft 1 temp 0.01 seqid 0.43 loss 1.51 dgram_cce 1.51 plddt 0.90 ptm 0.07 rmsd 0.46
# Stage 3: running (hard)
# 401 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.40
# 402 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.87 ptm 0.06 rmsd 0.35
# 403 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.40
# 404 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.87 ptm 0.06 rmsd 0.35
# 405 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.40
# 406 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.87 ptm 0.06 rmsd 0.35
# 407 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.40
# 408 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.87 ptm 0.06 rmsd 0.35
# 409 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.49 dgram_cce 1.49 plddt 0.89 ptm 0.07 rmsd 0.40
# 410 models [0, 1, 2, 3, 4] recycles 0 hard 1 soft 1 temp 0.01 seqid 0.43 loss 1.54 dgram_cce 1.54 plddt 0.87 ptm 0.06 rmsd 0.35

# %%
af_model.plot_traj()

# %%
af_model.save_pdb(f"{af_model.protocol}.pdb")
af_model.plot_pdb(show_mainchains=True)
# Out:
# <div id="3dmolviewer_17350108664923847"  style="position: relative; width: 800px; height: 480px;">
#         <p id="3dmolwarning_17350108664923847" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_17350108664923847 = null;
# var warn = document.getElementById("3dmolwarning_17350108664923847");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17350108664923847 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17350108664923847"),{backgroundColor:"white"});
# viewer_17350108664923847.zoomTo();
# 	viewer_17350108664923847.addModel("MODEL       1\nATOM      1  N   THR A   1      -0.677   1.026   6.327  1.00 86.23           N  \nATOM      2  CA  THR A   1      -0.925   2.138   7.239  1.00 86.23           C  \nATOM      3  C   THR A   1      -1.570   3.308   6.501  1.00 86.23           C  \nATOM      4  CB  THR A   1       0.376   2.607   7.914  1.00 86.23           C  \nATOM      5  O   THR A   1      -2.054   4.252   7.129  1.00 86.23           O  \nATOM      6  CG2 THR A   1       1.017   1.480   8.717  1.00 86.23           C  \nATOM      7  OG1 THR A   1       1.298   3.047   6.909  1.00 86.23           O  \nATOM      8  N   GLY A   2      -2.202   3.036   5.461  1.00 85.98           N  \nATOM      9  CA  GLY A   2      -2.948   4.057   4.743  1.00 85.98           C  \nATOM     10  C   GLY A   2      -2.057   5.067   4.044  1.00 85.98           C  \nATOM     11  O   GLY A   2      -2.537   5.892   3.264  1.00 85.98           O  \nATOM     12  N   TYR A   3      -0.809   5.080   4.120  1.00 84.98           N  \nATOM     13  CA  TYR A   3       0.213   5.832   3.401  1.00 84.98           C  \nATOM     14  C   TYR A   3       1.308   4.907   2.883  1.00 84.98           C  \nATOM     15  CB  TYR A   3       0.823   6.909   4.303  1.00 84.98           C  \nATOM     16  O   TYR A   3       1.530   3.828   3.437  1.00 84.98           O  \nATOM     17  CG  TYR A   3      -0.202   7.794   4.969  1.00 84.98           C  \nATOM     18  CD1 TYR A   3      -0.688   8.933   4.331  1.00 84.98           C  \nATOM     19  CD2 TYR A   3      -0.686   7.495   6.238  1.00 84.98           C  \nATOM     20  CE1 TYR A   3      -1.631   9.753   4.942  1.00 84.98           C  \nATOM     21  CE2 TYR A   3      -1.629   8.308   6.859  1.00 84.98           C  \nATOM     22  OH  TYR A   3      -3.029  10.241   6.813  1.00 84.98           O  \nATOM     23  CZ  TYR A   3      -2.095   9.433   6.204  1.00 84.98           C  \nATOM     24  N   ARG A   4       1.924   5.049   1.617  1.00 87.79           N  \nATOM     25  CA  ARG A   4       2.884   4.140   0.997  1.00 87.79           C  \nATOM     26  C   ARG A   4       4.307   4.461   1.440  1.00 87.79           C  \nATOM     27  CB  ARG A   4       2.781   4.208  -0.528  1.00 87.79           C  \nATOM     28  O   ARG A   4       4.780   5.586   1.261  1.00 87.79           O  \nATOM     29  CG  ARG A   4       3.216   2.933  -1.233  1.00 87.79           C  \nATOM     30  CD  ARG A   4       3.035   3.032  -2.741  1.00 87.79           C  \nATOM     31  NE  ARG A   4       1.642   3.282  -3.101  1.00 87.79           N  \nATOM     32  NH1 ARG A   4       1.833   2.456  -5.250  1.00 87.79           N  \nATOM     33  NH2 ARG A   4      -0.175   3.272  -4.505  1.00 87.79           N  \nATOM     34  CZ  ARG A   4       1.103   3.003  -4.285  1.00 87.79           C  \nATOM     35  N   ASP A   5       4.917   3.670   2.420  1.00 85.16           N  \nATOM     36  CA  ASP A   5       6.275   3.893   2.907  1.00 85.16           C  \nATOM     37  C   ASP A   5       7.154   2.668   2.662  1.00 85.16           C  \nATOM     38  CB  ASP A   5       6.261   4.241   4.397  1.00 85.16           C  \nATOM     39  O   ASP A   5       8.318   2.642   3.068  1.00 85.16           O  \nATOM     40  CG  ASP A   5       6.034   3.031   5.286  1.00 85.16           C  \nATOM     41  OD1 ASP A   5       7.020   2.378   5.692  1.00 85.16           O  \nATOM     42  OD2 ASP A   5       4.858   2.726   5.582  1.00 85.16           O  \nATOM     43  N   GLY A   6       7.096   2.022   1.779  1.00 83.71           N  \nATOM     44  CA  GLY A   6       7.987   0.958   1.344  1.00 83.71           C  \nATOM     45  C   GLY A   6       8.211  -0.103   2.405  1.00 83.71           C  \nATOM     46  O   GLY A   6       9.059  -0.983   2.240  1.00 83.71           O  \nATOM     47  N   SER A   7       7.585  -0.085   3.518  1.00 87.56           N  \nATOM     48  CA  SER A   7       7.729  -0.979   4.663  1.00 87.56           C  \nATOM     49   ...

# %%
HTML(af_model.animate())
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
af_model.get_seqs()
# Out:
# ['TGYRDGSGIP']

# %% [markdown]
# # hallucination (~1 minute)
# For a given length, generate/hallucinate a protein sequence that AlphaFold thinks folds into a well structured protein (high plddt, low pae, many contacts).

# %%
clear_mem()
af_model = mk_afdesign_model(protocol="hallucination")
af_model.prep_inputs(length=13, rm_aa="C")
add_cyclic_offset(af_model)
# add_rg_loss(af_model)

print("length",af_model._len)
print("weights",af_model.opt["weights"])

# %%
# pre-design with gumbel initialization and softmax activation
af_model.restart()
af_model.set_seq(mode="gumbel")
af_model.set_opt("con", binary=True, cutoff=21.6875, num=af_model._len, seqsep=0)
af_model.set_weights(pae=1, plddt=1, con=0.5)
af_model.design_soft(50)

# three stage design
af_model.set_seq(seq=af_model.aux["seq"]["pseudo"])
af_model.design_3stage(50,50,10)

# %%
af_model.save_pdb(f"{af_model.protocol}.pdb")
af_model.plot_pdb(show_mainchains=True)

# %%
HTML(af_model.animate())

# %%
af_model.get_seqs()
